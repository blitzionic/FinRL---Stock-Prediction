# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git

# %%
import pandas as pd
import numpy as np
import datetime
import yfinance as yf

# %%
nasdaq_csv = "NASDAQ_symbols.csv"
df = pd.read_csv(nasdaq_csv, delimiter=',')
df.to_csv("NASDAQ_symbols.csv", index=False)

# %%
df_nasdaq = pd.read_csv("NASDAQ.csv")
df_nasdaq.head
# Out:
# <bound method NDFrame.head of      Symbol                                      Description
# 0      AACG                        Ata Creativity Global ADR
# 1      AACI                        Armada Acquisition Corp I
# 2     AACIW                     Armada Acquisition Corp I WT
# 3      AADI                             Aadi Biosciences Inc
# 4      AADR                  Advisorshares Dorsey Wright ETF
# ...     ...                                              ...
# 4917   ZVRA                           Zevra Therapeutics Inc
# 4918   ZVSA                         Zyversa Therapeutics Inc
# 4919   ZYME                                    Zymeworks Inc
# 4920   ZYXI                                        Zynex Inc
# 4921    ZZZ  Cyber Hornet S&P 500 and Bitcoin 75/25 Strategy
#
# [4922 rows x 2 columns]>

# %%
import yfinance as yf
NASDAQ_tickers = df_nasdaq['Symbol'].tolist()

# %%
NASDAQ_tickers
# Out:
# ['AACG',
#  'AACI',
#  'AACIW',
#  'AADI',
#  'AADR',
#  'AAGR',
#  'AAGRW',
#  'AAL',
#  'AAME',
#  'AAOI',
#  'AAON',
#  'AAPB',
#  'AAPD',
#  'AAPL',
#  'AAPU',
#  'AAXJ',
#  'ABAT',
#  'ABCB',
#  'ABCL',
#  'ABCS',
#  'ABEO',
#  'ABIO',
#  'ABL',
#  'ABLLL',
#  'ABLLW',
#  'ABLV',
#  'ABLVW',
#  'ABNB',
#  'ABOS',
#  'ABSI',
#  'ABTS',
#  'ABUS',
#  'ABVC',
#  'ABVX',
#  'ACAB',
#  'ACABU',
#  'ACABW',
#  'ACAC',
#  'ACACW',
#  'ACAD',
#  'ACAH',
#  'ACAHW',
#  'ACB',
#  'ACBA',
#  'ACBAU',
#  'ACBAW',
#  'ACCD',
#  'ACDC',
#  'ACET',
#  'ACGL',
#  'ACGLN',
#  'ACGLO',
#  'ACHC',
#  'ACHL',
#  'ACHV',
#  'ACIC',
#  'ACIU',
#  'ACIW',
#  'ACLS',
#  'ACLX',
#  'ACMR',
#  'ACNB',
#  'ACNT',
#  'ACON',
#  'ACONW',
#  'ACOR',
#  'ACRS',
#  'ACRV',
#  'ACST',
#  'ACT',
#  'ACTG',
#  'ACVA',
#  'ACWI',
#  'ACWX',
#  'ACXP',
#  'ADAG',
#  'ADAP',
#  'ADBE',
#  'ADD',
#  'ADEA',
#  'ADI',
#  'ADIL',
#  'ADMA',
#  'ADN',
#  'ADNWW',
#  'ADOC',
#  'ADOCR',
#  'ADOCW',
#  'ADP',
#  'ADPT',
# ...

# %%
# filter out NAN tickers
NASDAQ_tickers = [str(ticker) for ticker in NASDAQ_tickers if pd.notna(ticker)]
len(NASDAQ_tickers)
# Out:
# 4921

# %%
# downloading 1 month of data
#nasdaq_stocks_jan_2024 = yf.download(NASDAQ_tickers, start="2024-01-05", end="2024-01-06")

# %%
import matplotlib.pyplot as plt

# %%
# Determine first day available on stocks  
ticker = yf.Ticker("AAPL")
historical_data = ticker.history(period="max")
earliest_index = historical_data.index.min()
earliest_index
# Out:
# Timestamp('1980-12-12 00:00:00-0500', tz='America/New_York')

# %%
# DOW30 Companies
DOW30_csv = "DOW30.csv"  
df_DOW30 = pd.read_csv(DOW30_csv)
DOW30_tickers = df_DOW30['Symbol'].tolist()

# %%
DOW30_tickers
# Out:
# ['AMZN',
#  'AXP',
#  'AMGN',
#  'AAPL',
#  'BA',
#  'CAT',
#  'CSCO',
#  'CVX',
#  'GS',
#  'HD',
#  'HON',
#  'IBM',
#  'INTC',
#  'JNJ',
#  'KO',
#  'JPM',
#  'MCD',
#  'MMM',
#  'MRK',
#  'MSFT',
#  'NKE',
#  'PG',
#  'TRV',
#  'UNH',
#  'CRM',
#  'VZ',
#  'V',
#  'WMT',
#  'DIS',
#  'DOW']

# %%
# download data for DOW30 - this method produces multiindexed data, which is not ideal
# 2023 Year
#DOW30_2023 = yf.download(tickers=DOW30_tickers, start="2024-01-05", end="2024-01-06")

# %%
# Retrieve data for DOW30 Companies for 2023 
DOW30_df_list = list()
for ticker in DOW30_tickers:
    data = yf.download(ticker, group_by="Ticker", start="2023-01-01", end="2023-12-31")
    data['ticker'] = ticker
    DOW30_df_list.append(data)

DOW30_df = pd.concat(DOW30_df_list)

DOW30_df.to_csv('DOW30_data.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...

# %%
# check for missing values
DOW30_df.isna().sum()
# Out:
# Open         0
# High         0
# Low          0
# Close        0
# Adj Close    0
# Volume       0
# ticker       0
# dtype: int64

# %%
# Retrieve data for 2023 
NASDAQ_df_list = list()         
for ticker in NASDAQ_tickers:
    data = yf.download(ticker, group_by="Ticker", start="2023-01-01", end="2023-12-31")
    data['ticker'] = ticker
    NASDAQ_df_list.append(data)

NASDAQ_df = pd.concat(NASDAQ_df_list)

NASDAQ_df.to_csv('NASDAQ_data.csv')
# Out:
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AACIW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
#
# 1 Failed download:
# ['AAGRW']: Exception("%ticker%: Period 'max' is invalid, must be one of ['1d', '5d']")
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# [*********************100%%**********************]  1 of 1 completed
# ...
