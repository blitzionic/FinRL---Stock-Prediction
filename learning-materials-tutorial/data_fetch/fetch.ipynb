# %%
## install required packages
# !pip install swig
# !pip install wrds
# !pip install pyportfolioopt
## install finrl library
# !pip install git+https://github.com/AI4Finance-Foundation/FinRL.git
# Out:
# Collecting swig
#   Using cached swig-4.2.1-py2.py3-none-win_amd64.whl.metadata (3.7 kB)
# Using cached swig-4.2.1-py2.py3-none-win_amd64.whl (2.6 MB)
# Installing collected packages: swig
# Successfully installed swig-4.2.1
# Collecting wrds
#   Using cached wrds-3.2.0-py3-none-any.whl.metadata (5.8 kB)
# Collecting numpy<1.27,>=1.26 (from wrds)
#   Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl.metadata (61 kB)
#      ---------------------------------------- 0.0/61.0 kB ? eta -:--:--
#      ---------------------------------------- 61.0/61.0 kB ? eta 0:00:00
# Requirement already satisfied: packaging<23.3 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from wrds) (23.1)
# Collecting pandas<2.3,>=2.2 (from wrds)
#   Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl.metadata (19 kB)
# Collecting psycopg2-binary<2.10,>=2.9 (from wrds)
#   Downloading psycopg2_binary-2.9.9-cp311-cp311-win_amd64.whl.metadata (4.6 kB)
# Collecting scipy<1.13,>=1.12 (from wrds)
#   Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB ? eta 0:00:00
# Collecting sqlalchemy<2.1,>=2 (from wrds)
#   Using cached SQLAlchemy-2.0.27-cp311-cp311-win_amd64.whl.metadata (9.8 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pandas<2.3,>=2.2->wrds) (2023.3)
# Collecting typing-extensions>=4.6.0 (from sqlalchemy<2.1,>=2->wrds)
#   Using cached typing_extensions-4.10.0-py3-none-any.whl.metadata (3.0 kB)
# Collecting greenlet!=0.4.17 (from sqlalchemy<2.1,>=2->wrds)
#   Downloading greenlet-3.0.3-cp311-cp311-win_amd64.whl.metadata (3.9 kB)
# Requirement already satisfied: six>=1.5 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas<2.3,>=2.2->wrds) (1.16.0)
# Downloading wrds-3.2.0-py3-none-any.whl (13 kB)
# Downloading numpy-1.26.4-cp311-cp311-win_amd64.whl (15.8 MB)
#    ---------------------------------------- 0.0/15.8 MB ? eta -:--:--
#    - -------------------------------------- 0.7/15.8 MB 22.4 MB/s eta 0:00:01
#    ---- ----------------------------------- 1.8/15.8 MB 22.6 MB/s eta 0:00:01
#    ------- -------------------------------- 3.1/15.8 MB 22.2 MB/s eta 0:00:01
#    ---------- ----------------------------- 4.2/15.8 MB 24.6 MB/s eta 0:00:01
#    ------------ --------------------------- 5.0/15.8 MB 23.0 MB/s eta 0:00:01
#    --------------- ------------------------ 6.1/15.8 MB 21.6 MB/s eta 0:00:01
#    ------------------ --------------------- 7.3/15.8 MB 22.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 8.7/15.8 MB 24.2 MB/s eta 0:00:01
#    ------------------------- -------------- 10.0/15.8 MB 24.6 MB/s eta 0:00:01
#    ---------------------------- ----------- 11.2/15.8 MB 25.1 MB/s eta 0:00:01
#    ------------------------------- -------- 12.3/15.8 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 13.5/15.8 MB 25.2 MB/s eta 0:00:01
#    ------------------------------------ --- 14.5/15.8 MB 25.2 MB/s eta 0:00:01
#    ---------------------------------------  15.8/15.8 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------------- 15.8/15.8 MB 24.2 MB/s eta 0:00:00
# Downloading pandas-2.2.1-cp311-cp311-win_amd64.whl (11.6 MB)
#    ---------------------------------------- 0.0/11.6 MB ? eta -:--:--
#    --- ------------------------------------ 1.1/11.6 MB 35.0 MB/s eta 0:00:01
#    ------- -------------------------------- 2.2/11.6 MB 28.4 MB/s eta 0:00:01
#    ----------- ---------------------------- 3.2/11.6 MB 25.9 MB/s eta 0:00:01
#    --------------- ------------------------ 4.6/11.6 MB 26.8 MB/s eta 0:00:01
#    ------------------ --------------------- 5.4/11.6 MB 24.9 MB/s eta 0:00:01
#    ---------------------- ----------------- 6.5/11.6 MB 24.5 MB/s eta 0:00:01
#    -------------------------- ------------- 7.7/11.6 MB 24.7 MB/s eta 0:00:01
#    ----------------------------- ---------- 8.6/11.6 MB 24.0 MB/s eta 0:00:01
#    ---------------------------------- ----- 9.9/11.6 MB 24.4 MB/s eta 0:00:01
#    -------------------------------------- - 11.2/11.6 MB 24.2 MB/s eta 0:00:01
#    ---------------------------------------- 11.6/11.6 MB 22.5 MB/s eta 0:00:00
# Downloading psycopg2_binary-2.9.9-cp311-cp311-win_amd64.whl (1.2 MB)
#    ---------------------------------------- 0.0/1.2 MB ? eta -:--:--
#    ------------------------------- -------- 0.9/1.2 MB 29.4 MB/s eta 0:00:01
#    ---------------------------------------- 1.2/1.2 MB 24.5 MB/s eta 0:00:00
# Downloading scipy-1.12.0-cp311-cp311-win_amd64.whl (46.2 MB)
#    ---------------------------------------- 0.0/46.2 MB ? eta -:--:--
#     --------------------------------------- 1.0/46.2 MB 31.7 MB/s eta 0:00:02
#    - -------------------------------------- 2.1/46.2 MB 26.7 MB/s eta 0:00:02
#    -- ------------------------------------- 3.3/46.2 MB 26.6 MB/s eta 0:00:02
#    --- ------------------------------------ 4.4/46.2 MB 25.5 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.5/46.2 MB 24.9 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.5/46.2 MB 24.3 MB/s eta 0:00:02
#    ------ --------------------------------- 7.4/46.2 MB 23.8 MB/s eta 0:00:02
#    ------- -------------------------------- 8.7/46.2 MB 24.2 MB/s eta 0:00:02
#    -------- ------------------------------- 10.1/46.2 MB 24.8 MB/s eta 0:00:02
#    --------- ------------------------------ 11.0/46.2 MB 24.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 11.9/46.2 MB 23.4 MB/s eta 0:00:02
#    ---------- ----------------------------- 12.6/46.2 MB 22.6 MB/s eta 0:00:02
#    ----------- ---------------------------- 13.7/46.2 MB 22.6 MB/s eta 0:00:02
#    ------------ --------------------------- 14.9/46.2 MB 22.5 MB/s eta 0:00:02
#    ------------- -------------------------- 16.1/46.2 MB 22.6 MB/s eta 0:00:02
#    --------------- ------------------------ 17.3/46.2 MB 23.4 MB/s eta 0:00:02
#    ---------------- ----------------------- 18.6/46.2 MB 24.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 19.8/46.2 MB 23.4 MB/s eta 0:00:02
#    ------------------ --------------------- 20.9/46.2 MB 23.4 MB/s eta 0:00:02
#    ------------------ --------------------- 21.8/46.2 MB 24.2 MB/s eta 0:00:02
#    ------------------- -------------------- 22.7/46.2 MB 24.2 MB/s eta 0:00:01
#    -------------------- ------------------- 23.5/46.2 MB 24.2 MB/s eta 0:00:01
#    --------------------- ------------------ 24.8/46.2 MB 24.3 MB/s eta 0:00:01
#    ---------------------- ----------------- 25.8/46.2 MB 23.4 MB/s eta 0:00:01
#    ----------------------- ---------------- 27.1/46.2 MB 23.4 MB/s eta 0:00:01
#    ------------------------ --------------- 28.2/46.2 MB 23.4 MB/s eta 0:00:01
#    ------------------------- -------------- 29.4/46.2 MB 23.4 MB/s eta 0:00:01
#    -------------------------- ------------- 30.5/46.2 MB 22.6 MB/s eta 0:00:01
#    --------------------------- ------------ 31.8/46.2 MB 24.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 33.1/46.2 MB 25.1 MB/s eta 0:00:01
#    ----------------------------- ---------- 34.1/46.2 MB 25.2 MB/s eta 0:00:01
#    ------------------------------ --------- 35.1/46.2 MB 25.2 MB/s eta 0:00:01
#    ------------------------------- -------- 36.1/46.2 MB 25.2 MB/s eta 0:00:01
#    ------------------------------- -------- 36.8/46.2 MB 23.4 MB/s eta 0:00:01
#    -------------------------------- ------- 37.8/46.2 MB 22.6 MB/s eta 0:00:01
#    --------------------------------- ------ 38.9/46.2 MB 22.6 MB/s eta 0:00:01
#    ---------------------------------- ----- 39.6/46.2 MB 21.8 MB/s eta 0:00:01
#    ----------------------------------- ---- 40.8/46.2 MB 21.8 MB/s eta 0:00:01
#    ------------------------------------ --- 41.8/46.2 MB 21.9 MB/s eta 0:00:01
#    ------------------------------------ --- 42.5/46.2 MB 20.5 MB/s eta 0:00:01
#    ------------------------------------- -- 43.3/46.2 MB 19.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.1/46.2 MB 19.9 MB/s eta 0:00:01
#    -------------------------------------- - 44.9/46.2 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------  45.6/46.2 MB 19.3 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------  46.2/46.2 MB 18.7 MB/s eta 0:00:01
#    ---------------------------------------- 46.2/46.2 MB 16.4 MB/s eta 0:00:00
# Downloading SQLAlchemy-2.0.27-cp311-cp311-win_amd64.whl (2.1 MB)
#    ---------------------------------------- 0.0/2.1 MB ? eta -:--:--
#    -------------- ------------------------- 0.8/2.1 MB 15.9 MB/s eta 0:00:01
#    -------------------------------- ------- 1.7/2.1 MB 17.9 MB/s eta 0:00:01
#    ---------------------------------------- 2.1/2.1 MB 16.5 MB/s eta 0:00:00
# Downloading greenlet-3.0.3-cp311-cp311-win_amd64.whl (292 kB)
#    ---------------------------------------- 0.0/292.8 kB ? eta -:--:--
#    --------------------------------------- 292.8/292.8 kB 17.7 MB/s eta 0:00:00
# Using cached typing_extensions-4.10.0-py3-none-any.whl (33 kB)
# Installing collected packages: typing-extensions, psycopg2-binary, numpy, greenlet, sqlalchemy, scipy, pandas, wrds
#   Attempting uninstall: typing-extensions
#     Found existing installation: typing_extensions 4.5.0
#     Uninstalling typing_extensions-4.5.0:
#       Successfully uninstalled typing_extensions-4.5.0
#   Attempting uninstall: numpy
#     Found existing installation: numpy 1.24.3
#     Uninstalling numpy-1.24.3:
#       Successfully uninstalled numpy-1.24.3
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.11.1
#     Uninstalling scipy-1.11.1:
#       Successfully uninstalled scipy-1.11.1
#   Attempting uninstall: pandas
#     Found existing installation: pandas 2.0.3
#     Uninstalling pandas-2.0.3:
#       Successfully uninstalled pandas-2.0.3
# Successfully installed greenlet-3.0.3 numpy-1.26.4 pandas-2.2.1 psycopg2-binary-2.9.9 scipy-1.12.0 sqlalchemy-2.0.27 typing-extensions-4.10.0 wrds-3.2.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# tensorflow-intel 2.13.0 requires numpy<=1.24.3,>=1.22, but you have numpy 1.26.4 which is incompatible.
# tensorflow-intel 2.13.0 requires typing-extensions<4.6.0,>=3.6.6, but you have typing-extensions 4.10.0 which is incompatible.
# Collecting pyportfolioopt
#   Using cached pyportfolioopt-1.5.5-py3-none-any.whl.metadata (23 kB)
# Collecting cvxpy<2.0.0,>=1.1.19 (from pyportfolioopt)
#   Downloading cvxpy-1.4.2-cp311-cp311-win_amd64.whl.metadata (9.0 kB)
# Requirement already satisfied: numpy<2.0.0,>=1.22.4 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pyportfolioopt) (1.26.4)
# Requirement already satisfied: pandas>=0.19 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pyportfolioopt) (2.2.1)
# Requirement already satisfied: scipy<2.0,>=1.3 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pyportfolioopt) (1.12.0)
# Collecting osqp>=0.6.2 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt)
#   Downloading osqp-0.6.5-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Collecting ecos>=2 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt)
#   Downloading ecos-2.0.13-cp311-cp311-win_amd64.whl.metadata (8.2 kB)
# Collecting clarabel>=0.5.0 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt)
#   Downloading clarabel-0.7.0-cp37-abi3-win_amd64.whl.metadata (4.7 kB)
# Collecting scs>=3.0 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt)
#   Downloading scs-3.2.4.post1-cp311-cp311-win_amd64.whl.metadata (2.1 kB)
# Collecting pybind11 (from cvxpy<2.0.0,>=1.1.19->pyportfolioopt)
#   Downloading pybind11-2.11.1-py3-none-any.whl.metadata (9.5 kB)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2023.3)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from pandas>=0.19->pyportfolioopt) (2023.3)
# Collecting scipy<2.0,>=1.3 (from pyportfolioopt)
#   Downloading scipy-1.11.4-cp311-cp311-win_amd64.whl.metadata (60 kB)
#      ---------------------------------------- 0.0/60.4 kB ? eta -:--:--
#      ---------------------------------------- 60.4/60.4 kB 3.3 MB/s eta 0:00:00
# Collecting qdldl (from osqp>=0.6.2->cvxpy<2.0.0,>=1.1.19->pyportfolioopt)
#   Downloading qdldl-0.1.7.post0-cp311-cp311-win_amd64.whl.metadata (1.8 kB)
# Requirement already satisfied: six>=1.5 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from python-dateutil>=2.8.2->pandas>=0.19->pyportfolioopt) (1.16.0)
# Downloading pyportfolioopt-1.5.5-py3-none-any.whl (61 kB)
#    ---------------------------------------- 0.0/61.9 kB ? eta -:--:--
#    ---------------------------------------- 61.9/61.9 kB ? eta 0:00:00
# Downloading cvxpy-1.4.2-cp311-cp311-win_amd64.whl (1.0 MB)
#    ---------------------------------------- 0.0/1.0 MB ? eta -:--:--
#    -------------------------------- ------- 0.8/1.0 MB 27.1 MB/s eta 0:00:01
#    ---------------------------------------- 1.0/1.0 MB 16.3 MB/s eta 0:00:00
# Downloading clarabel-0.7.0-cp37-abi3-win_amd64.whl (341 kB)
#    ---------------------------------------- 0.0/341.5 kB ? eta -:--:--
#    --------------------------------------- 341.5/341.5 kB 20.7 MB/s eta 0:00:00
# Downloading ecos-2.0.13-cp311-cp311-win_amd64.whl (72 kB)
#    ---------------------------------------- 0.0/72.0 kB ? eta -:--:--
#    ---------------------------------------- 72.0/72.0 kB 3.9 MB/s eta 0:00:00
# Downloading osqp-0.6.5-cp311-cp311-win_amd64.whl (293 kB)
#    ---------------------------------------- 0.0/293.1 kB ? eta -:--:--
#    --------------------------------------- 293.1/293.1 kB 18.9 MB/s eta 0:00:00
# Downloading scipy-1.11.4-cp311-cp311-win_amd64.whl (44.1 MB)
#    ---------------------------------------- 0.0/44.1 MB ? eta -:--:--
#    - -------------------------------------- 1.4/44.1 MB 29.4 MB/s eta 0:00:02
#    -- ------------------------------------- 2.6/44.1 MB 27.7 MB/s eta 0:00:02
#    --- ------------------------------------ 3.8/44.1 MB 26.8 MB/s eta 0:00:02
#    ---- ----------------------------------- 5.2/44.1 MB 27.7 MB/s eta 0:00:02
#    ----- ---------------------------------- 6.4/44.1 MB 27.4 MB/s eta 0:00:02
#    ------- -------------------------------- 7.7/44.1 MB 27.5 MB/s eta 0:00:02
#    ------- -------------------------------- 8.8/44.1 MB 26.8 MB/s eta 0:00:02
#    -------- ------------------------------- 8.9/44.1 MB 23.8 MB/s eta 0:00:02
#    --------- ------------------------------ 10.9/44.1 MB 26.2 MB/s eta 0:00:02
#    ---------- ----------------------------- 12.1/44.1 MB 26.2 MB/s eta 0:00:02
#    ------------ --------------------------- 13.4/44.1 MB 26.2 MB/s eta 0:00:02
#    ------------- -------------------------- 14.4/44.1 MB 25.2 MB/s eta 0:00:02
#    -------------- ------------------------- 15.5/44.1 MB 25.2 MB/s eta 0:00:02
#    --------------- ------------------------ 17.0/44.1 MB 25.2 MB/s eta 0:00:02
#    ---------------- ----------------------- 18.2/44.1 MB 25.2 MB/s eta 0:00:02
#    ----------------- ---------------------- 19.4/44.1 MB 28.5 MB/s eta 0:00:01
#    ------------------ --------------------- 20.4/44.1 MB 26.2 MB/s eta 0:00:01
#    ------------------- -------------------- 21.3/44.1 MB 25.1 MB/s eta 0:00:01
#    -------------------- ------------------- 22.7/44.1 MB 25.1 MB/s eta 0:00:01
#    --------------------- ------------------ 23.9/44.1 MB 25.2 MB/s eta 0:00:01
#    ---------------------- ----------------- 25.1/44.1 MB 25.2 MB/s eta 0:00:01
#    ----------------------- ---------------- 26.3/44.1 MB 25.2 MB/s eta 0:00:01
#    ------------------------- -------------- 27.6/44.1 MB 26.2 MB/s eta 0:00:01
#    ------------------------- -------------- 28.7/44.1 MB 25.2 MB/s eta 0:00:01
#    --------------------------- ------------ 30.0/44.1 MB 25.2 MB/s eta 0:00:01
#    ---------------------------- ----------- 31.3/44.1 MB 27.3 MB/s eta 0:00:01
#    ----------------------------- ---------- 32.5/44.1 MB 27.3 MB/s eta 0:00:01
#    ------------------------------ --------- 33.7/44.1 MB 27.3 MB/s eta 0:00:01
#    ------------------------------- -------- 35.1/44.1 MB 27.3 MB/s eta 0:00:01
#    -------------------------------- ------- 36.2/44.1 MB 27.3 MB/s eta 0:00:01
#    --------------------------------- ------ 37.3/44.1 MB 26.2 MB/s eta 0:00:01
#    ---------------------------------- ----- 38.6/44.1 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------ --- 39.8/44.1 MB 27.3 MB/s eta 0:00:01
#    ------------------------------------- -- 41.2/44.1 MB 27.3 MB/s eta 0:00:01
#    -------------------------------------- - 42.5/44.1 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------  43.8/44.1 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------  44.1/44.1 MB 27.3 MB/s eta 0:00:01
#    ---------------------------------------- 44.1/44.1 MB 23.3 MB/s eta 0:00:00
# Downloading scs-3.2.4.post1-cp311-cp311-win_amd64.whl (8.4 MB)
#    ---------------------------------------- 0.0/8.4 MB ? eta -:--:--
#    ----- ---------------------------------- 1.2/8.4 MB 37.7 MB/s eta 0:00:01
#    ------------ --------------------------- 2.5/8.4 MB 32.3 MB/s eta 0:00:01
#    ------------------ --------------------- 3.9/8.4 MB 31.0 MB/s eta 0:00:01
#    ------------------------ --------------- 5.2/8.4 MB 30.2 MB/s eta 0:00:01
#    ------------------------------ --------- 6.4/8.4 MB 29.2 MB/s eta 0:00:01
#    ------------------------------------ --- 7.7/8.4 MB 28.9 MB/s eta 0:00:01
#    ---------------------------------------  8.4/8.4 MB 28.2 MB/s eta 0:00:01
#    ---------------------------------------- 8.4/8.4 MB 25.6 MB/s eta 0:00:00
# Downloading pybind11-2.11.1-py3-none-any.whl (227 kB)
#    ---------------------------------------- 0.0/227.7 kB ? eta -:--:--
#    --------------------------------------- 227.7/227.7 kB 13.6 MB/s eta 0:00:00
# Downloading qdldl-0.1.7.post0-cp311-cp311-win_amd64.whl (85 kB)
#    ---------------------------------------- 0.0/85.1 kB ? eta -:--:--
#    ---------------------------------------- 85.1/85.1 kB 4.7 MB/s eta 0:00:00
# Installing collected packages: scipy, pybind11, scs, qdldl, ecos, clarabel, osqp, cvxpy, pyportfolioopt
#   Attempting uninstall: scipy
#     Found existing installation: scipy 1.12.0
#     Uninstalling scipy-1.12.0:
#       Successfully uninstalled scipy-1.12.0
# Successfully installed clarabel-0.7.0 cvxpy-1.4.2 ecos-2.0.13 osqp-0.6.5 pybind11-2.11.1 pyportfolioopt-1.5.5 qdldl-0.1.7.post0 scipy-1.11.4 scs-3.2.4.post1
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# wrds 3.2.0 requires scipy<1.13,>=1.12, but you have scipy 1.11.4 which is incompatible.
# Collecting git+https://github.com/AI4Finance-Foundation/FinRL.git
#   Cloning https://github.com/AI4Finance-Foundation/FinRL.git to c:\users\andyz\appdata\local\temp\pip-req-build-xarmw2tk
#   Resolved https://github.com/AI4Finance-Foundation/FinRL.git to commit e4ca1e76abd519ee670267d6c212dd62abf2d627
#   Installing build dependencies: started
#   Installing build dependencies: finished with status 'done'
#   Getting requirements to build wheel: started
#   Getting requirements to build wheel: finished with status 'done'
#   Preparing metadata (pyproject.toml): started
#   Preparing metadata (pyproject.toml): finished with status 'done'
# Collecting elegantrl@ git+https://github.com/AI4Finance-Foundation/ElegantRL.git#egg=elegantrl (from finrl==0.3.6)
#   Cloning https://github.com/AI4Finance-Foundation/ElegantRL.git to c:\users\andyz\appdata\local\temp\pip-install-xra9z23q\elegantrl_9fa88e05696d42e88333f0f80b4cc342
#   Resolved https://github.com/AI4Finance-Foundation/ElegantRL.git to commit b4b9d662b9f9cb7cc368ac2b1036b5119eb20be4
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Collecting alpaca-trade-api<4,>=3 (from finrl==0.3.6)
#   Using cached alpaca_trade_api-3.2.0-py3-none-any.whl.metadata (29 kB)
# Collecting ccxt<4,>=3 (from finrl==0.3.6)
#   Using cached ccxt-3.1.60-py2.py3-none-any.whl.metadata (108 kB)
# Collecting exchange-calendars<5,>=4 (from finrl==0.3.6)
#   Using cached exchange_calendars-4.5.3-py3-none-any.whl.metadata (37 kB)
# Collecting jqdatasdk<2,>=1 (from finrl==0.3.6)
#   Using cached jqdatasdk-1.9.2-py3-none-any.whl.metadata (5.7 kB)
# Collecting pyfolio<0.10,>=0.9 (from finrl==0.3.6)
#   Using cached pyfolio-0.9.2.tar.gz (91 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Requirement already satisfied: pyportfolioopt<2,>=1 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from finrl==0.3.6) (1.5.5)
# Collecting ray<3,>=2 (from ray[default,tune]<3,>=2->finrl==0.3.6)
#   Using cached ray-2.9.3-cp311-cp311-win_amd64.whl.metadata (14 kB)
# Requirement already satisfied: scikit-learn<2,>=1 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from finrl==0.3.6) (1.3.0)
# Collecting stable-baselines3>=2.0.0a5 (from stable-baselines3[extra]>=2.0.0a5->finrl==0.3.6)
#   Using cached stable_baselines3-2.3.0a2-py3-none-any.whl.metadata (5.1 kB)
# Collecting stockstats<0.6,>=0.5 (from finrl==0.3.6)
#   Using cached stockstats-0.5.4-py2.py3-none-any.whl.metadata (26 kB)
# Requirement already satisfied: wrds<4,>=3 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from finrl==0.3.6) (3.2.0)
# Requirement already satisfied: yfinance<0.3,>=0.2 in c:\users\andyz\appdata\local\programs\python\python311\lib\site-packages (from finrl==0.3.6) (0.2.37)
# INFO: pip is looking at multiple versions of finrl to determine which version is compatible with other requirements. This could take a while.
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/FinRL.git 'C:\Users\andyz\AppData\Local\Temp\pip-req-build-xarmw2tk'
#   Running command git clone --filter=blob:none --quiet https://github.com/AI4Finance-Foundation/ElegantRL.git 'C:\Users\andyz\AppData\Local\Temp\pip-install-xra9z23q\elegantrl_9fa88e05696d42e88333f0f80b4cc342'
# ERROR: Package 'finrl' requires a different Python: 3.11.4 not in '<3.11,>=3.10'

# %%
# !pip install box2d-py
# !pip install box2d
# !pip install Box2D
# Out:
# Collecting box2d-py
#   Using cached box2d-py-2.3.8.tar.gz (374 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: box2d-py
#   Building wheel for box2d-py (setup.py): started
#   Building wheel for box2d-py (setup.py): finished with status 'error'
#   Running setup.py clean for box2d-py
# Failed to build box2d-py
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Using setuptools (version 65.5.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\Box2D
#       copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-311\Box2D
#       copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-311\Box2D
#       creating build\lib.win-amd64-cpython-311\Box2D\b2
#       copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-311\Box2D\b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#       swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#       Box2D\Common\b2Math.h(67) : Warning 302: Redefinition of identifier 'b2Vec2' by %extend ignored,
#       Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#       Box2D\Common\b2Math.h(158) : Warning 302: Redefinition of identifier 'b2Vec3' by %extend ignored,
#       Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#       Box2D\Common\b2Math.h(197) : Warning 302: Redefinition of identifier 'b2Mat22' by %extend ignored,
#       Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#       Box2D\Common\b2Math.h(271) : Warning 302: Redefinition of identifier 'b2Mat33' by %extend ignored,
#       Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#       Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#       Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#       Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#       Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d-py
# ERROR: Could not build wheels for box2d-py, which is required to install pyproject.toml-based projects
# Collecting box2d
#   Using cached Box2D-2.3.2.tar.gz (427 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: box2d
#   Building wheel for box2d (setup.py): started
#   Building wheel for box2d (setup.py): finished with status 'error'
#   Running setup.py clean for box2d
# Failed to build box2d
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Using setuptools (version 65.5.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\Box2D
#       copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-311\Box2D
#       copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-311\Box2D
#       creating build\lib.win-amd64-cpython-311\Box2D\b2
#       copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-311\Box2D\b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#       swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#       Box2D\Common\b2Math.h(67) : Warning 302: Redefinition of identifier 'b2Vec2' by %extend ignored,
#       Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#       Box2D\Common\b2Math.h(158) : Warning 302: Redefinition of identifier 'b2Vec3' by %extend ignored,
#       Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#       Box2D\Common\b2Math.h(197) : Warning 302: Redefinition of identifier 'b2Mat22' by %extend ignored,
#       Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#       Box2D\Common\b2Math.h(271) : Warning 302: Redefinition of identifier 'b2Mat33' by %extend ignored,
#       Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#       Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#       Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#       Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#       Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for box2d
# ERROR: Could not build wheels for box2d, which is required to install pyproject.toml-based projects
# Collecting Box2D
#   Using cached Box2D-2.3.2.tar.gz (427 kB)
#   Preparing metadata (setup.py): started
#   Preparing metadata (setup.py): finished with status 'done'
# Building wheels for collected packages: Box2D
#   Building wheel for Box2D (setup.py): started
#   Building wheel for Box2D (setup.py): finished with status 'error'
#   Running setup.py clean for Box2D
# Failed to build Box2D
#   error: subprocess-exited-with-error
#
#   × python setup.py bdist_wheel did not run successfully.
#   │ exit code: 1
#   ╰─> [28 lines of output]
#       Using setuptools (version 65.5.0).
#       running bdist_wheel
#       running build
#       running build_py
#       creating build
#       creating build\lib.win-amd64-cpython-311
#       creating build\lib.win-amd64-cpython-311\Box2D
#       copying library\Box2D\Box2D.py -> build\lib.win-amd64-cpython-311\Box2D
#       copying library\Box2D\__init__.py -> build\lib.win-amd64-cpython-311\Box2D
#       creating build\lib.win-amd64-cpython-311\Box2D\b2
#       copying library\Box2D\b2\__init__.py -> build\lib.win-amd64-cpython-311\Box2D\b2
#       running build_ext
#       building 'Box2D._Box2D' extension
#       swigging Box2D\Box2D.i to Box2D\Box2D_wrap.cpp
#       swig.exe -python -c++ -IBox2D -small -O -includeall -ignoremissing -w201 -globals b2Globals -outdir library\Box2D -keyword -w511 -D_SWIG_KWARGS -o Box2D\Box2D_wrap.cpp Box2D\Box2D.i
#       Box2D\Common\b2Math.h(67) : Warning 302: Redefinition of identifier 'b2Vec2' by %extend ignored,
#       Box2D\Box2D_math.i(47) : Warning 302: %extend definition of 'b2Vec2'.
#       Box2D\Common\b2Math.h(158) : Warning 302: Redefinition of identifier 'b2Vec3' by %extend ignored,
#       Box2D\Box2D_math.i(168) : Warning 302: %extend definition of 'b2Vec3'.
#       Box2D\Common\b2Math.h(197) : Warning 302: Redefinition of identifier 'b2Mat22' by %extend ignored,
#       Box2D\Box2D_math.i(301) : Warning 302: %extend definition of 'b2Mat22'.
#       Box2D\Common\b2Math.h(271) : Warning 302: Redefinition of identifier 'b2Mat33' by %extend ignored,
#       Box2D\Box2D_math.i(372) : Warning 302: %extend definition of 'b2Mat33'.
#       Box2D\Collision\b2DynamicTree.h(44) : Warning 312: Nested union not currently supported (ignored).
#       Box2D\Common\b2Settings.h(144) : Warning 506: Can't wrap varargs with keyword arguments enabled
#       Box2D\Common\b2Math.h(91) : Warning 509: Overloaded method b2Vec2::operator ()(int32) effectively ignored,
#       Box2D\Common\b2Math.h(85) : Warning 509: as it is shadowed by b2Vec2::operator ()(int32) const.
#       error: Microsoft Visual C++ 14.0 or greater is required. Get it with "Microsoft C++ Build Tools": https://visualstudio.microsoft.com/visual-cpp-build-tools/
#       [end of output]
#
#   note: This error originates from a subprocess, and is likely not a problem with pip.
#   ERROR: Failed building wheel for Box2D
# ERROR: Could not build wheels for Box2D, which is required to install pyproject.toml-based projects

# %%
import pandas as pd
import numpy as np
import datetime
import yfinance as yf


#import YahooDownloader
#from finrl.meta.preprocessor.preprocessors import FeatureEngineer, data_split
#from finrl import config_tickers
#from finrl.config import INDICATORS

#import itertools

# %%
aapl_df_yf = yf.download(tickers = "aapl", start='2020-01-01', end='2020-01-31')
# Out:
# [*********************100%%**********************]  1 of 1 completed

# %%
aapl_df_yf.head()
aapl = yf.Ticker("AAPL")

aapl.info
# Out:
# {'address1': 'One Apple Park Way',
#  'city': 'Cupertino',
#  'state': 'CA',
#  'zip': '95014',
#  'country': 'United States',
#  'phone': '408 996 1010',
#  'website': 'https://www.apple.com',
#  'industry': 'Consumer Electronics',
#  'industryKey': 'consumer-electronics',
#  'industryDisp': 'Consumer Electronics',
#  'sector': 'Technology',
#  'sectorKey': 'technology',
#  'sectorDisp': 'Technology',
#  'longBusinessSummary': 'Apple Inc. designs, manufactures, and markets smartphones, personal computers, tablets, wearables, and accessories worldwide. The company offers iPhone, a line of smartphones; Mac, a line of personal computers; iPad, a line of multi-purpose tablets; and wearables, home, and accessories comprising AirPods, Apple TV, Apple Watch, Beats products, and HomePod. It also provides AppleCare support and cloud services; and operates various platforms, including the App Store that allow customers to discover and download applications and digital content, such as books, music, video, games, and podcasts. In addition, the company offers various services, such as Apple Arcade, a game subscription service; Apple Fitness+, a personalized fitness service; Apple Music, which offers users a curated listening experience with on-demand radio stations; Apple News+, a subscription news and magazine service; Apple TV+, which offers exclusive original content; Apple Card, a co-branded credit card; and Apple Pay, a cashless payment service, as well as licenses its intellectual property. The company serves consumers, and small and mid-sized businesses; and the education, enterprise, and government markets. It distributes third-party applications for its products through the App Store. The company also sells its products through its retail and online stores, and direct sales force; and third-party cellular network carriers, wholesalers, retailers, and resellers. Apple Inc. was founded in 1976 and is headquartered in Cupertino, California.',
#  'fullTimeEmployees': 161000,
#  'companyOfficers': [{'maxAge': 1,
#    'name': 'Mr. Timothy D. Cook',
#    'age': 62,
#    'title': 'CEO & Director',
#    'yearBorn': 1961,
#    'fiscalYear': 2023,
#    'totalPay': 16239562,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Luca  Maestri',
#    'age': 60,
#    'title': 'CFO & Senior VP',
#    'yearBorn': 1963,
#    'fiscalYear': 2023,
#    'totalPay': 4612242,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Jeffrey E. Williams',
#    'age': 59,
#    'title': 'Chief Operating Officer',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4637585,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Ms. Katherine L. Adams',
#    'age': 59,
#    'title': 'Senior VP, General Counsel & Secretary',
#    'yearBorn': 1964,
#    'fiscalYear': 2023,
#    'totalPay': 4618064,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': "Ms. Deirdre  O'Brien",
#    'age': 56,
#    'title': 'Senior Vice President of Retail',
#    'yearBorn': 1967,
#    'fiscalYear': 2023,
#    'totalPay': 4613369,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Chris  Kondo',
#    'title': 'Senior Director of Corporate Accounting',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. James  Wilson',
#    'title': 'Chief Technology Officer',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Suhasini  Chandramouli',
#    'title': 'Director of Investor Relations',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Greg  Joswiak',
#    'title': 'Senior Vice President of Worldwide Marketing',
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0},
#   {'maxAge': 1,
#    'name': 'Mr. Adrian  Perica',
#    'age': 49,
#    'title': 'Head of Corporate Development',
#    'yearBorn': 1974,
#    'fiscalYear': 2023,
#    'exercisedValue': 0,
#    'unexercisedValue': 0}],
#  'auditRisk': 4,
#  'boardRisk': 1,
#  'compensationRisk': 5,
#  'shareHolderRightsRisk': 1,
#  'overallRisk': 1,
#  'governanceEpochDate': 1709078400,
#  'compensationAsOfEpochDate': 1703980800,
#  'maxAge': 86400,
#  'priceHint': 2,
#  'previousClose': 180.75,
#  'open': 179.68,
#  'dayLow': 177.38,
#  'dayHigh': 180.53,
#  'regularMarketPreviousClose': 180.75,
#  'regularMarketOpen': 179.68,
#  'regularMarketDayLow': 177.38,
#  'regularMarketDayHigh': 180.53,
#  'dividendRate': 0.96,
#  'dividendYield': 0.0053,
#  'exDividendDate': 1707436800,
#  'payoutRatio': 0.14770001,
#  'fiveYearAvgDividendYield': 0.76,
#  'beta': 1.312,
#  'trailingPE': 27.940903,
#  'forwardPE': 25.057182,
#  'volume': 72176475,
#  'regularMarketVolume': 72176475,
#  'averageVolume': 56096820,
#  'averageVolume10days': 58843330,
#  'averageDailyVolume10Day': 58843330,
#  'bid': 179.03,
#  'ask': 179.73,
#  'bidSize': 900,
#  'askSize': 1400,
#  'marketCap': 2774291709952,
#  'fiftyTwoWeekLow': 147.33,
#  'fiftyTwoWeekHigh': 199.62,
#  'priceToSalesTrailing12Months': 7.192763,
#  'fiftyDayAverage': 187.7194,
#  'twoHundredDayAverage': 183.9042,
#  'trailingAnnualDividendRate': 0.95,
#  'trailingAnnualDividendYield': 0.0052558784,
#  'currency': 'USD',
#  'enterpriseValue': 2826059907072,
#  'profitMargins': 0.26163,
#  'floatShares': 15414548871,
#  'sharesOutstanding': 15441899520,
#  'sharesShort': 97665956,
#  'sharesShortPriorMonth': 101263039,
#  'sharesShortPreviousMonthDate': 1705017600,
#  'dateShortInterest': 1707955200,
#  'sharesPercentSharesOut': 0.0063,
#  'heldPercentInsiders': 0.059369996,
#  'heldPercentInstitutions': 0.56676996,
#  'shortRatio': 1.71,
#  'shortPercentOfFloat': 0.0063,
#  'impliedSharesOutstanding': 15441899520,
#  'bookValue': 4.793,
#  'priceToBook': 37.48383,
#  'lastFiscalYearEnd': 1696032000,
#  'nextFiscalYearEnd': 1727654400,
#  'mostRecentQuarter': 1703894400,
#  'earningsQuarterlyGrowth': 0.131,
#  'netIncomeToCommon': 100912996352,
#  'trailingEps': 6.43,
#  'forwardEps': 7.17,
#  'pegRatio': 2.51,
#  'lastSplitFactor': '4:1',
#  'lastSplitDate': 1598832000,
#  'enterpriseToRevenue': 7.327,
#  'enterpriseToEbitda': 21.721,
#  '52WeekChange': 0.19678211,
#  'SandP52WeekChange': 0.25969434,
#  'lastDividendValue': 0.24,
#  'lastDividendDate': 1707436800,
#  'exchange': 'NMS',
#  'quoteType': 'EQUITY',
#  'symbol': 'AAPL',
#  'underlyingSymbol': 'AAPL',
#  'shortName': 'Apple Inc.',
#  'longName': 'Apple Inc.',
#  'firstTradeDateEpochUtc': 345479400,
#  'timeZoneFullName': 'America/New_York',
#  'timeZoneShortName': 'EST',
#  'uuid': '8b10e4ae-9eeb-3684-921a-9ab27e4d87aa',
#  'messageBoardId': 'finmb_24937',
#  'gmtOffSetMilliseconds': -18000000,
#  'currentPrice': 179.66,
#  'targetHighPrice': 250.0,
#  'targetLowPrice': 158.0,
#  'targetMeanPrice': 201.41,
#  'targetMedianPrice': 200.0,
#  'recommendationMean': 2.2,
#  'recommendationKey': 'buy',
#  'numberOfAnalystOpinions': 39,
#  'totalCash': 73100001280,
#  'totalCashPerShare': 4.734,
#  'ebitda': 130108997632,
#  'totalDebt': 108040003584,
#  'quickRatio': 0.92,
#  'currentRatio': 1.073,
#  'totalRevenue': 385706000384,
#  'debtToEquity': 145.803,
#  'revenuePerShare': 24.648,
#  'returnOnAssets': 0.21181,
#  'returnOnEquity': 1.5426899,
#  'freeCashflow': 86563127296,
#  'operatingCashflow': 116433002496,
#  'earningsGrowth': 0.16,
#  'revenueGrowth': 0.021,
#  'grossMargins': 0.45027,
#  'ebitdaMargins': 0.33733,
#  'operatingMargins': 0.33764,
#  'financialCurrency': 'USD',
#  'trailingPegRatio': 2.2249}

# %%
hist = aapl.history(period="max")

# %%
hist
# Out:
#                                  Open        High         Low       Close  \
# Date
# 1980-12-12 00:00:00-05:00    0.099192    0.099623    0.099192    0.099192
# 1980-12-15 00:00:00-05:00    0.094448    0.094448    0.094017    0.094017
# 1980-12-16 00:00:00-05:00    0.087548    0.087548    0.087117    0.087117
# 1980-12-17 00:00:00-05:00    0.089273    0.089704    0.089273    0.089273
# 1980-12-18 00:00:00-05:00    0.091861    0.092292    0.091861    0.091861
# ...                               ...         ...         ...         ...
# 2024-02-26 00:00:00-05:00  182.240005  182.759995  180.649994  181.160004
# 2024-02-27 00:00:00-05:00  181.100006  183.919998  179.559998  182.630005
# 2024-02-28 00:00:00-05:00  182.509995  183.119995  180.130005  181.419998
# 2024-02-29 00:00:00-05:00  181.270004  182.570007  179.529999  180.750000
# 2024-03-01 00:00:00-05:00  179.679993  180.529999  177.380005  179.660004
#
#                               Volume  Dividends  Stock Splits
# Date
# 1980-12-12 00:00:00-05:00  469033600        0.0           0.0
# 1980-12-15 00:00:00-05:00  175884800        0.0           0.0
# 1980-12-16 00:00:00-05:00  105728000        0.0           0.0
# 1980-12-17 00:00:00-05:00   86441600        0.0           0.0
# 1980-12-18 00:00:00-05:00   73449600        0.0           0.0
# ...                              ...        ...           ...
# 2024-02-26 00:00:00-05:00   40867400        0.0           0.0
# 2024-02-27 00:00:00-05:00   54318900        0.0           0.0
# 2024-02-28 00:00:00-05:00   48953900        0.0           0.0
# 2024-02-29 00:00:00-05:00  136682600        0.0           0.0
# 2024-03-01 00:00:00-05:00   72176475        0.0           0.0
#
# [10895 rows x 7 columns]

# %%
aapl.splits
# Out:
# Date
# 1987-06-16 00:00:00-04:00    2.0
# 2000-06-21 00:00:00-04:00    2.0
# 2005-02-28 00:00:00-05:00    2.0
# 2014-06-09 00:00:00-04:00    7.0
# 2020-08-31 00:00:00-04:00    4.0
# Name: Stock Splits, dtype: float64
